# %%
import csv
from datetime import datetime

#. 파일을 읽습니다.
file = open("D:\data\경상남도_통영시_통영시립욕지도서관보유도서목록현황_20230208.csv", 
            'r',
           encoding = 'UTF-8')

#. csv 라이브러리가  csv 파일을 읽을 수 있도록 변환합니다.
reader = csv.reader(file)

# 도서관명, 등록번호, 자료명, 저자명, 발행처,발행연도,관리기관명, 데이터기준일자

is_header = True
books = []
datetime_format = "%Y-%m-%d"

for line in reader:
    if is_header == True:
        is_header = False
        continue
    
    if len(line) < 8 :
        continue
        
    book = {
        "library_name" : line[0], 
        "book_number": int(line[1]), 
        "book_name": line[2],
        "author" : line[3],
        "publisher": line[4],
        "publish_year": line[5],
        "sido" : line[6],
        "create_date": datetime.strptime(line[7], datetime_format)
    }
    books.append(book)
    
len(books)
# Out:
# 50753

# %%
import pymongo
import pandas as pd

# Mongodb와 연결합니다.
client = pymongo.MongoClient("mongodb://localhost:27017")

collection = client['test']['books']

# 대량의 데이터를  Insert 한다. insert_many
# print("--------------------------------- START ------------------------")
# collection.insert_many(books)
# print("--------------------------------- END ---------------------------")
datas = list(collection.find().limit(10))

datas = pd.DataFrame(datas)

datas
# Out:
#                         _id library_name  book_number              book_name  \
# 0  63e5e02be0ffba6ec86ff10c    통영시립욕지도서관            1                    노자익
# 1  63e5e02be0ffba6ec86ff10d    통영시립욕지도서관            2                     논어
# 2  63e5e02be0ffba6ec86ff10e    통영시립욕지도서관            3                 표류공주 1
# 3  63e5e02be0ffba6ec86ff10f    통영시립욕지도서관            4                 표류공주 2
# 4  63e5e02be0ffba6ec86ff110    통영시립욕지도서관            5                 표류공주 3
# 5  63e5e02be0ffba6ec86ff111    통영시립욕지도서관            6                 표류공주 4
# 6  63e5e02be0ffba6ec86ff112    통영시립욕지도서관            7        三國志 1  도원에 피는 의
# 7  63e5e02be0ffba6ec86ff113    통영시립욕지도서관            8        三國志 2  구름처럼이는영웅
# 8  63e5e02be0ffba6ec86ff114    통영시립욕지도서관            9         三國志 3  헝클어진 천하
# 9  63e5e02be0ffba6ec86ff115    통영시립욕지도서관           10  三國志 4  칼한자루 말한필로천리를닫다
#
#            author publisher publish_year          sido create_date
# 0   焦횡弱侯 집  이현주 역        두레         2000  경상남도 통영시 욕지면  2023-02-08
# 1          박정수 엮음       청목사         2001  경상남도 통영시 욕지면  2023-02-08
# 2           최후식 저       시공사         2000  경상남도 통영시 욕지면  2023-02-08
# 3           최후식 저       시공사         2000  경상남도 통영시 욕지면  2023-02-08
# 4           최후식 저       시공사         2000  경상남도 통영시 욕지면  2023-02-08
# 5           최후식 저       시공사         2000  경상남도 통영시 욕지면  2023-02-08
# 6  나관중 지음  이문열 평역       민음사         2000  경상남도 통영시 욕지면  2023-02-08
# 7  나관중 지음  이문열 평역       민음사         2001  경상남도 통영시 욕지면  2023-02-08
# 8  나관중 지음  이문열 평역       민음사         2001  경상남도 통영시 욕지면  2023-02-08
# 9  나관중 지음  이문열 평역       민음사         2001  경상남도 통영시 욕지면  2023-02-08

# %%
import pymongo
import pandas as pd

# Mongodb와 연결합니다.
client = pymongo.MongoClient("mongodb://localhost:27017")

collection = client['test']['books']
datas = list(collection.find({ "author" : "" }))

datas = pd.DataFrame(datas)

datas
